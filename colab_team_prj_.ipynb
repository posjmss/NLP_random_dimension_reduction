# %%
# clone my repo
# !git clone https://github.com/posjmss/NLP_random_dimension_reduction.git
# Out:
# Cloning into 'NLP_random_dimension_reduction'...
# remote: Enumerating objects: 296, done.
# remote: Counting objects: 100% (296/296), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 296 (delta 181), reused 289 (delta 174), pack-reused 0 (from 0)
# Receiving objects: 100% (296/296), 371.79 KiB | 3.15 MiB/s, done.
# Resolving deltas: 100% (181/181), done.

# %%
# check clone correctly
# %cd NLP_random_dimension_reduction
# !ls
# Out:
# [Errno 2] No such file or directory: 'NLP_random_dimension_reduction'
# /content/drive/MyDrive/NLP_random_dimension_reduction/outputs
# one_dim_drop_beir

# %%
# dependency: uv install
# !pip install uv
# Out:
# Collecting uv
#   Downloading uv-0.11.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.11.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 115.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: uv
# Successfully installed uv-0.11.7

# %%
# git pull (update latest)
# !git pull
# Out:
# Already up to date.

# %%
# dimension attribution analysis - NanoBEIR (13 datasets)
# embedding: Sentence-T5 base
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_beir/main.py --config src/random_embedding_truncation/dimension_attribution_analysis_beir/configs/t5-base.toml
# Out:
# Using CPython 3.12.8
# Creating virtual environment at: .venv
# Installed 140 packages in 1.16s
# modules.json: 100% 461/461 [00:00<00:00, 4.15MB/s]
# config_sentence_transformers.json: 100% 122/122 [00:00<00:00, 1.30MB/s]
# README.md: 1.78kB [00:00, 8.60MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 464kB/s]
# config.json: 1.39kB [00:00, 7.06MB/s]
# model.safetensors: 100% 219M/219M [00:02<00:00, 95.3MB/s]
# tokenizer_config.json: 1.92kB [00:00, 9.87MB/s]
# spiece.model: 100% 792k/792k [00:00<00:00, 1.69MB/s]
# tokenizer.json: 1.39MB [00:00, 67.1MB/s]
# special_tokens_map.json: 1.79kB [00:00, 10.3MB/s]
# config.json: 100% 190/190 [00:00<00:00, 1.79MB/s]
# config.json: 100% 115/115 [00:00<00:00, 1.30MB/s]
# 2_Dense/pytorch_model.bin:   0% 0.00/2.36M [00:00<?, ?B/s]
# 2_Dense/model.safetensors:   0% 0.00/2.36M [00:00<?, ?B/s]
#
# 2_Dense/pytorch_model.bin: 100% 2.36M/2.36M [00:00<00:00, 3.42MB/s]
#
#
# 2_Dense/rust_model.ot: 100% 2.36M/2.36M [00:00<00:00, 2.66MB/s]
#
# 2_Dense/model.safetensors: 100% 2.36M/2.36M [00:00<00:00, 2.55MB/s]
# README.md: 1.10kB [00:00, 6.91MB/s]
# corpus/train-00000-of-00001.parquet: 100% 3.33M/3.33M [00:02<00:00, 1.48MB/s]
# Generating train split: 100% 3408/3408 [00:00<00:00, 117860.08 examples/s]
# queries/train-00000-of-00001.parquet: 100% 7.57k/7.57k [00:00<00:00, 14.3kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 21254.20 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 3.77k/3.77k [00:00<00:00, 7.89kB/s]
# Generating train split: 100% 148/148 [00:00<00:00, 63033.81 examples/s]
# README.md: 1.10kB [00:00, 5.46MB/s]
# corpus/train-00000-of-00001.parquet: 100% 1.48M/1.48M [00:02<00:00, 693kB/s]
# Generating train split: 100% 6045/6045 [00:00<00:00, 512472.31 examples/s]
# queries/train-00000-of-00001.parquet: 100% 3.55k/3.55k [00:00<00:00, 7.14kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 21355.93 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 23.2k/23.2k [00:00<00:00, 46.7kB/s]
# Generating train split: 100% 1158/1158 [00:00<00:00, 417878.69 examples/s]
# README.md: 1.09kB [00:00, 7.00MB/s]
# corpus/train-00000-of-00001.parquet: 100% 3.93M/3.93M [00:00<00:00, 5.38MB/s]
# Generating train split: 100% 4996/4996 [00:00<00:00, 176928.83 examples/s]
# queries/train-00000-of-00001.parquet: 100% 3.88k/3.88k [00:00<00:00, 7.76kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 19349.99 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 2.73k/2.73k [00:00<00:00, 5.47kB/s]
# Generating train split: 100% 57/57 [00:00<00:00, 24784.92 examples/s]
# README.md: 1.09kB [00:00, 7.30MB/s]
# corpus/train-00000-of-00001.parquet: 100% 2.53M/2.53M [00:00<00:00, 4.28MB/s]
# Generating train split: 100% 4598/4598 [00:00<00:00, 225131.15 examples/s]
# queries/train-00000-of-00001.parquet: 100% 4.25k/4.25k [00:00<00:00, 8.11kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 18869.46 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 2.63k/2.63k [00:00<00:00, 5.15kB/s]
# Generating train split: 100% 123/123 [00:00<00:00, 55312.47 examples/s]
# README.md: 1.09kB [00:00, 5.28MB/s]
# corpus/train-00000-of-00001.parquet: 100% 1.25M/1.25M [00:02<00:00, 574kB/s]
# Generating train split: 100% 5090/5090 [00:00<00:00, 439316.14 examples/s]
# queries/train-00000-of-00001.parquet: 100% 6.43k/6.43k [00:00<00:00, 12.7kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 12588.70 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 3.42k/3.42k [00:00<00:00, 7.25kB/s]
# Generating train split: 100% 100/100 [00:00<00:00, 42616.38 examples/s]
# README.md: 1.09kB [00:00, 7.00MB/s]
# corpus/train-00000-of-00001.parquet: 100% 1.12M/1.12M [00:00<00:00, 2.00MB/s]
# Generating train split: 100% 5043/5043 [00:00<00:00, 438217.35 examples/s]
# queries/train-00000-of-00001.parquet: 100% 3.22k/3.22k [00:00<00:00, 6.10kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 22894.67 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 2.10k/2.10k [00:00<00:00, 4.04kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 21966.61 examples/s]
# README.md: 1.10kB [00:00, 7.40MB/s]
# corpus/train-00000-of-00001.parquet: 100% 2.46M/2.46M [00:00<00:00, 3.78MB/s]
# Generating train split: 100% 2953/2953 [00:00<00:00, 131692.16 examples/s]
# queries/train-00000-of-00001.parquet: 100% 2.79k/2.79k [00:00<00:00, 4.96kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 21779.54 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 16.3k/16.3k [00:00<00:00, 33.3kB/s]
# Generating train split: 100% 2518/2518 [00:00<00:00, 783185.57 examples/s]
# README.md: 1.09kB [00:00, 5.63MB/s]
# corpus/train-00000-of-00001.parquet: 100% 1.78M/1.78M [00:00<00:00, 3.03MB/s]
# Generating train split: 100% 5035/5035 [00:00<00:00, 364693.74 examples/s]
# queries/train-00000-of-00001.parquet: 100% 3.66k/3.66k [00:00<00:00, 7.30kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 21079.02 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 2.02k/2.02k [00:00<00:00, 4.02kB/s]
# Generating train split: 100% 57/57 [00:00<00:00, 25679.41 examples/s]
# README.md: 1.10kB [00:00, 7.23MB/s]
# corpus/train-00000-of-00001.parquet: 100% 229k/229k [00:00<00:00, 405kB/s]
# Generating train split: 100% 5046/5046 [00:00<00:00, 1038236.84 examples/s]
# queries/train-00000-of-00001.parquet: 100% 3.92k/3.92k [00:00<00:00, 7.87kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 21217.64 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 2.27k/2.27k [00:00<00:00, 4.39kB/s]
# Generating train split: 100% 70/70 [00:00<00:00, 28983.34 examples/s]
# README.md: 1.10kB [00:00, 5.55MB/s]
# corpus/train-00000-of-00001.parquet: 100% 1.27M/1.27M [00:02<00:00, 580kB/s]
# Generating train split: 100% 2210/2210 [00:00<00:00, 183295.01 examples/s]
# queries/train-00000-of-00001.parquet: 100% 6.87k/6.87k [00:00<00:00, 13.9kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 19948.18 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 14.0k/14.0k [00:00<00:00, 26.5kB/s]
# Generating train split: 100% 244/244 [00:00<00:00, 102782.98 examples/s]
# README.md: 1.17kB [00:00, 1.26MB/s]
# corpus/train-00000-of-00001.parquet: 100% 2.21M/2.21M [00:02<00:00, 928kB/s]
# Generating train split: 100% 3635/3635 [00:00<00:00, 195743.88 examples/s]
# queries/train-00000-of-00001.parquet: 100% 45.6k/45.6k [00:00<00:00, 80.0kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 15006.45 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 3.44k/3.44k [00:00<00:00, 6.92kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 22790.18 examples/s]
# README.md: 1.09kB [00:00, 7.06MB/s]
# corpus/train-00000-of-00001.parquet: 100% 2.41M/2.41M [00:00<00:00, 3.63MB/s]
# Generating train split: 100% 2919/2919 [00:00<00:00, 151402.63 examples/s]
# queries/train-00000-of-00001.parquet: 100% 5.48k/5.48k [00:00<00:00, 10.2kB/s]
# Generating train split: 100% 50/50 [00:00<00:00, 21522.50 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 2.08k/2.08k [00:00<00:00, 4.24kB/s]
# Generating train split: 100% 56/56 [00:00<00:00, 23807.12 examples/s]
# README.md: 1.10kB [00:00, 7.44MB/s]
# corpus/train-00000-of-00001.parquet: 100% 7.27M/7.27M [00:00<00:00, 11.6MB/s]
# Generating train split: 100% 5745/5745 [00:00<00:00, 113487.17 examples/s]
# queries/train-00000-of-00001.parquet: 100% 3.35k/3.35k [00:00<00:00, 6.15kB/s]
# Generating train split: 100% 49/49 [00:00<00:00, 22204.07 examples/s]
# qrels/train-00000-of-00001.parquet: 100% 17.7k/17.7k [00:00<00:00, 35.7kB/s]
# Generating train split: 100% 932/932 [00:00<00:00, 389003.02 examples/s]
# Exception ignored in: <function CachedEmbeddingWrapper.__del__ at 0x7c2743e8e8e0>
# Traceback (most recent call last):
#   File "/content/NLP_random_dimension_reduction/.venv/lib/python3.12/site-packages/mteb/models/cache_wrapper.py", line 304, in __del__
#   File "/content/NLP_random_dimension_reduction/.venv/lib/python3.12/site-packages/mteb/models/cache_wrapper.py", line 308, in close
#   File "/content/NLP_random_dimension_reduction/.venv/lib/python3.12/site-packages/mteb/models/cache_wrapper.py", line 199, in close
# AttributeError: 'NoneType' object has no attribute 'info'
# Exception ignored in: <function TextVectorMap.__del__ at 0x7c2743e8e520>
# Traceback (most recent call last):
#   File "/content/NLP_random_dimension_reduction/.venv/lib/python3.12/site-packages/mteb/models/cache_wrapper.py", line 192, in __del__
#   File "/content/NLP_random_dimension_reduction/.venv/lib/python3.12/site-packages/mteb/models/cache_wrapper.py", line 199, in close
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
# dimension attribution analysis - NanoBEIR (13 datasets)
# embedding: E5-large-v2
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_beir/main.py --config src/random_embedding_truncation/dimension_attribution_analysis_beir/configs/e5-large-v2.toml
# Out:
# modules.json: 100% 387/387 [00:00<00:00, 3.51MB/s]
# README.md: 67.8kB [00:00, 77.0MB/s]
# sentence_bert_config.json: 100% 57.0/57.0 [00:00<00:00, 627kB/s]
# config.json: 100% 616/616 [00:00<00:00, 6.44MB/s]
# model.safetensors: 100% 1.34G/1.34G [00:11<00:00, 114MB/s]
# tokenizer_config.json: 100% 314/314 [00:00<00:00, 3.26MB/s]
# vocab.txt: 232kB [00:00, 45.5MB/s]
# tokenizer.json: 711kB [00:00, 77.7MB/s]
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 1.19MB/s]
# config.json: 100% 201/201 [00:00<00:00, 1.73MB/s]
# Dimension file not found. Vector dimension remains uninitialized.
# No existing files found. Initialized empty TextVectorMap (no_task_name).
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Hash collision or duplicate text. Overwriting existing vector.
# Exception ignored in: <function CachedEmbeddingWrapper.__del__ at 0x78a7f2509940>
# Traceback (most recent call last):
#   File "/content/NLP_random_dimension_reduction/.venv/lib/python3.12/site-packages/mteb/models/cache_wrapper.py", line 304, in __del__
#   File "/content/NLP_random_dimension_reduction/.venv/lib/python3.12/site-packages/mteb/models/cache_wrapper.py", line 308, in close
#   File "/content/NLP_random_dimension_reduction/.venv/lib/python3.12/site-packages/mteb/models/cache_wrapper.py", line 199, in close
# AttributeError: 'NoneType' object has no attribute 'info'
# Exception ignored in: <function TextVectorMap.__del__ at 0x78a7f2509580>
# Traceback (most recent call last):
#   File "/content/NLP_random_dimension_reduction/.venv/lib/python3.12/site-packages/mteb/models/cache_wrapper.py", line 192, in __del__
#   File "/content/NLP_random_dimension_reduction/.venv/lib/python3.12/site-packages/mteb/models/cache_wrapper.py", line 199, in close
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
# dimension attribution analysis - MTEB (12 datasets)
# embedding: Sentence-T5 base
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_mteb/main.py --config src/random_embedding_truncation/dimension_attribution_analysis_mteb/configs/t5-base.toml

# %%
# dimension attribution analysis - MTEB (12 datasets)
# embedding: E5-large-v2
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_mteb/main.py --config src/random_embedding_truncation/dimension_attribution_analysis_mteb/configs/e5-large-v2.toml

# %%
# collect mteb - sentence-T5 results
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_mteb/collect_results.py --config src/random_embedding_truncation/dimension_attribution_analysis_mteb/configs/t5-base.toml
# Out:
# /content

# %%
# collect mteb - e5-large results
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_mteb/collect_results.py --config src/random_embedding_truncation/dimension_attribution_analysis_mteb/configs/e5-large-v2.toml
# Out:
# /content
