# %%
# clone my repo
# !git clone https://github.com/posjmss/NLP_random_dimension_reduction.git

# %%
# check clone correctly
# %cd NLP_random_dimension_reduction
# !ls

# %%
# dependency: uv install
# !pip install uv

# %%
# git pull (update latest)
# !git pull

# %%
################################################## Start

# %%
# 1. BEIR t5-base
## 1-a. Dimension attribution analysis - NanoBEIR (13 datasets)
# embed: sentence-T5 base
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_beir/main.py --config /src/random_embedding_truncation/dimension_attribution_analysis_beir/configs/t5-base.toml

# %%
## 1-b. calculate baseline (full-embedding) - NanoBEIR
# embed: sentence-T5 base
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_beir/baseline.py --config /src/random_embedding_truncation/dimension_attribution_analysis_beir/configs/t5-base.toml

# %%
## 1-c. results sumary
# BEIR - t5
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_beir/collect_results.py --config /src/random_embedding_truncation/dimension_attribution_analysis_beir/configs/t5-base.toml

# %%
## 1-d. make dimension score
# BEIR - t5
# !!!!! should select one metric below
# %cd NLP_random_dimension_reduction
# metric: ndcg@10
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_scores.py --embedding t5-base --benchmark beir --metric NanoBEIR_mean_cosine_ndcg@10
# metric: ndcg@5
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_scores.py --embedding t5-base --benchmark beir --metric NanoBEIR_mean_cosine_ndcg@5

# %%
## 1-e. pairwise dimension reduction
# only helpful (2,4,10,20,40,100)
# only harmful (2,4,10,20,40,100)
# helpful-harmful (1-1/2-2/5-5/10-10/20-20/50-50)
# BEIR - t5
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/pairwise_dimension_reduction_beir/main.py --config /src/random_embedding_truncation/pairwise_dimension_reduction_beir/configs/t5-base.toml

# %%
################################################## NanoBEIR sentence-t5 end

# %%
# 2. BEIR e5-large-v2
## 2-a. Dimension attribution analysis - NanoBEIR (13 datasets)
# embed: e5-large
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_beir/main.py --config /src/random_embedding_truncation/dimension_attribution_analysis_beir/configs/e5-large-v2.toml

# %%
## 2-b. calculate baseline (full-embedding) - NanoBEIR
# embed: e5-large
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_beir/baseline.py --config /src/random_embedding_truncation/dimension_attribution_analysis_beir/configs/e5-large-v2.toml

# %%
## 2-c. results sumary
# BEIR - e5-large
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_beir/collect_results.py --config /src/random_embedding_truncation/dimension_attribution_analysis_beir/configs/e5-large-v2.toml

# %%
## 2-d. make dimension score
# BEIR - e5-large
# !!!!! should select one metric below
# %cd NLP_random_dimension_reduction
# metric: ndcg@10
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_scores.py --embedding e5-large-v2 --benchmark beir --metric NanoBEIR_mean_cosine_ndcg@10
# metric: ndcg@5
#!PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_scores.py --embedding e5-large-v2 --benchmark beir --metric NanoBEIR_mean_cosine_ndcg@5

# %%
## 2-e. pairwise dimension reduction
# only helpful (2,4,10,20,40,100)
# only harmful (2,4,10,20,40,100)
# helpful-harmful (1-1/2-2/5-5/10-10/20-20/50-50)# BEIR - e5-large
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/pairwise_dimension_reduction_beir/main.py --config ./src/random_embedding_truncation/pairwise_dimension_reduction_beir/configs/e5-large-v2.toml

# %%
################################################## NanoBEIR e5-large end

# %%
# 3. MTEB t5-base
## 3-a. Dimension attribution analysis - MTEB (12 classification tasks)
# embed: sentence-T5 base
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_mteb/main.py --config /src/random_embedding_truncation/dimension_attribution_analysis_mteb/configs/t5-base.toml

# %%
## 3-b. calculate baseline (full-embedding) - MTEB
# embed: sentence-T5 base
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_mteb/baseline.py --config /src/random_embedding_truncation/dimension_attribution_analysis_mteb/configs/t5-base.toml

# %%
## 3-c. results sumary
# MTEB - t5
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_mteb/collect_results.py --config /src/random_embedding_truncation/dimension_attribution_analysis_mteb/configs/t5-base.toml

# %%
## 3-d. make dimension score
# MTEB - t5
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_scores.py --embedding t5-base --benchmark mteb --metric MTEB_mean_scores_test_0_main_score

# %%
## 3-e. pairwise dimension reduction
# only helpful (2,4,10,20,40,100)
# only harmful (2,4,10,20,40,100)
# helpful-harmful (1-1/2-2/5-5/10-10/20-20/50-50)
# MTEB - t5
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/pairwise_dimension_reduction_mteb/main.py --config /src/random_embedding_truncation/pairwise_dimension_reduction_mteb/configs/t5-base.toml

# %%
############################################### MTEB sentence-t5 end

# %%
# 4. MTEB e5-large-v2
## 4-a. Dimension attribution analysis - MTEB (12 classification tasks)
# embed: e5-large-v2
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_mteb/main.py --config /src/random_embedding_truncation/dimension_attribution_analysis_mteb/configs/e5-large-v2.toml

# %%
## 4-b. calculate baseline (full-embedding) - MTEB
# embed: e5-large-v2
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_mteb/baseline.py --config /src/random_embedding_truncation/dimension_attribution_analysis_mteb/configs/e5-large-v2.toml

# %%
## 4-c. results sumary
# MTEB - e5-large
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_analysis_mteb/collect_results.py --config /src/random_embedding_truncation/dimension_attribution_analysis_mteb/configs/e5-large-v2.toml

# %%
## 4-d. make dimension score
# MTEB - e5-large
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/dimension_attribution_scores.py --embedding e5-large-v2 --benchmark mteb --metric MTEB_mean_scores_test_0_main_score

# %%
## 4-e. pairwise dimension reduction
# only helpful (2,4,10,20,40,100)
# only harmful (2,4,10,20,40,100)
# helpful-harmful (1-1/2-2/5-5/10-10/20-20/50-50)
# MTEB - t5
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/pairwise_dimension_reduction_mteb/main.py --config /src/random_embedding_truncation/pairwise_dimension_reduction_mteb/configs/e5-large-v2.toml

# %%
################################################## MTEB e5 end

# %%
# 5.Plot results
# 5-a. Plot Dimension attribution analysis - all models in output_summary
# !!!!! should select one metric below
# %cd NLP_random_dimension_reduction
# NanoBEIR : metric - ndcg@10
# !PYTHONPATH=src uv run python src/random_embedding_truncation/plotting/dim_att_analysis_beir/main.py --metric NanoBEIR_mean_cosine_ndcg@10
# NanoBEIR : metric - ndcg@5
#!PYTHONPATH=src uv run python src/random_embedding_truncation/plotting/dim_att_analysis_beir/main.py --metric NanoBEIR_mean_cosine_ndcg@5

# %%
# 5-b. Plot Dimension attribution analysis - all models in output_summary
# MTEB
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/plotting/dim_att_analysis_mteb/main.py

# %%
# 5-c. Plot Pairwise dimension reduction - all models in pairwise result dirs
# !!!!! should select one metric below
# %cd NLP_random_dimension_reduction
# NanoBEIR: metric ndcg@10
# !PYTHONPATH=src uv run python src/random_embedding_truncation/plotting/pairwise_dim_truncation_beir/main.py --metric NanoBEIR_mean_cosine_ndcg@10
# NanoBEIR: metric ndcg@5
#!PYTHONPATH=src uv run python src/random_embedding_truncation/plotting/pairwise_dim_truncation_beir/main.py --metric NanoBEIR_mean_cosine_ndcg@5

# %%
# 5-d. Plot Pairwise dimension reduction - all models in pairwise result dirs
# MTEB
# %cd NLP_random_dimension_reduction
# !PYTHONPATH=src uv run python src/random_embedding_truncation/plotting/pairwise_dim_truncation_mteb/main.py

# %%
################################################## Plot end

# %%
# Plot output(graphs) directory: NLP_random_dimension_reduction/figures
# Dimension scores (helpful/harmful coded for each dimension): NLP_random_dimension_reduction/output_dim_eval
